# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from [the Iowa website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy) in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %%
import pandas as pd

## Load the data into a DataFrame
df = pd.read_csv('../Resources/Iowa_Liquor_sales_sample_10pct_train.csv')

df.head()

# build on train dataset


## Transform the dates if needed, e.g.
# df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y")
# Out:
#    Unnamed: 0        Date  Store Number        City Zip Code  County Number  \
# 0      219336  06/16/2015          2518     RED OAK    51566           69.0
# 1      140585  08/20/2015          2616     CLINTON    52732           23.0
# 2       96074  11/12/2015          4902    WATERLOO    50703            7.0
# 3      269070  01/05/2016          2565     SPENCER    51301           21.0
# 4        5531  11/12/2015          2633  DES MOINES    50320           77.0
#
#        County   Category              Category Name  Vendor Number  \
# 0  Montgomery  1081315.0          CINNAMON SCHNAPPS            380
# 1     Clinton  1011200.0  STRAIGHT BOURBON WHISKIES            259
# 2  Black Hawk  1032080.0             IMPORTED VODKA            260
# 3        Clay  1081330.0             PEACH SCHNAPPS            434
# 4        Polk  1062300.0               FLAVORED RUM             65
#
#    Item Number                    Item Description  Bottle Volume (ml)  \
# 0        84636  Phillips Hot 100 Cinnamon Schnapps                 750
# 1        18046           Evan Williams Green Label                 750
# 2        34456            Ketel One Imported Vodka                 750
# 3        82127                Arrow Peach Schnapps                1000
# 4        44557               Cruzan Strawberry Rum                 750
#
#   State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 0             $7.45              $11.18             1         $11.18
# 1             $5.47               $8.21            12         $98.52
# 2            $14.00              $21.00             2         $42.00
# 3             $5.00               $7.50             3         $22.50
# 4             $6.83              $10.25             1         $10.25
#
#    Volume Sold (Liters)  Volume Sold (Gallons)
# 0                  0.75                   0.20
# 1                  9.00                   2.38
# 2                  1.50                   0.40
# 3                  3.00                   0.79
# 4                  0.75                   0.20

# %%
some_values = df[pd.isnull(df["County"])]["City"].value_counts().sort_values().index.tolist()
# print df['County'].isin(some_values)
df.loc[df['City'].isin(some_values)]
# Out:
#         Unnamed: 0        Date  Store Number          City Zip Code  \
# 1           140585  08/20/2015          2616       CLINTON    52732
# 2            96074  11/12/2015          4902      WATERLOO    50703
# 4             5531  11/12/2015          2633    DES MOINES    50320
# 5           166654  01/20/2016          2670    CORALVILLE    52241
# 10           74578  07/20/2015          5129    DES MOINES    50321
# 11          148396  12/08/2015          3514    FORT DODGE    50501
# 12           46429  09/16/2015          2594    SIOUX CITY    51106
# 14           55429  11/17/2015          2624       DUBUQUE    52002
# 16           51353  01/06/2016          4308    CORALVILLE    52241
# 21          106922  02/29/2016          2643      WATERLOO    50701
# 23          203396  10/14/2015          4057    DES MOINES    50316
# 25          124010  10/12/2015          3618  CEDAR RAPIDS    52404
# 26          252748  03/31/2015          2508  CEDAR RAPIDS    52405
# 29          264581  01/13/2015          2637     DAVENPORT    52804
# 42          207411  02/25/2015          2625     DAVENPORT    52804
# 43          111134  11/19/2015          4795    DES MOINES    50317
# 46          258180  05/11/2015          2590  CEDAR RAPIDS    52402
# 49           88361  03/08/2016          2524       DUBUQUE    52001
# 50          157701  07/06/2015          4223     EVANSDALE    50707
# 53          138788  02/25/2015          4062    DES MOINES    50314
# 54           57048  05/04/2015          2643      WATERLOO    50701
# 59          202949  04/14/2015          4431    FORT DODGE    50501
# 62          165282  06/18/2015          2561    DES MOINES    50321
# 66          264465  06/16/2015          4167       DUBUQUE    52001
# 69           60490  09/17/2015          4840      WATERLOO    50707
# 72          219828  10/15/2015          3993      WATERLOO    50701
# 74          253591  03/23/2015          4596    DES MOINES    50317
# 75          248493  07/23/2015          5132    DES MOINES    50315
# 82          120782  06/01/2015          2554     DAVENPORT    52802
# 83           99394  07/01/2015          2515    MASON CITY    50401
# ...            ...         ...           ...           ...      ...
# 243792      145090  03/31/2015          4764    FORT DODGE    50501
# 243793      166086  02/16/2016          2649       DUBUQUE    52001
# 243795      197704  11/05/2015          2561    DES MOINES    50321
# 243796       15618  08/11/2015          4765       DUBUQUE    52001
# 243797       51667  03/25/2015          4062    DES MOINES    50314
# 243798      113965  01/27/2016          3820    SIOUX CITY    51103
# 243800       54791  03/24/2016          4092       NORWALK    50211
# 243803      164557  01/13/2015          4452    SIOUX CITY    51105
# 243807       75769  12/02/2015          3873    CORALVILLE    52241
# 243809       27170  04/28/2015          2353        CRESCO    52136
# 243810       19731  11/05/2015          2626    DES MOINES    50311
# 243812       84155  08/06/2015          4642      WATERLOO    50701
# 243813      245468  01/27/2016          5172  CEDAR RAPIDS    52404
# 243821       25504  06/23/2015          2649       DUBUQUE    52001
# 243822       65817  02/23/2016          4471      WATERLOO    50702
# 243825       74908  02/18/2016          2528    DES MOINES    50315
# 243826      218317  11/20/2015          2588  CEDAR RAPIDS    52403
# 243829      200406  11/11/2015          2852    DES MOINES    50310
# 243837      140054  07/16/2015          4214      WATERLOO    50703
# 243839       64286  05/11/2015          3644       ALTOONA    50009
# 243840       21999  05/26/2015          4167       DUBUQUE    52001
# 243843      104807  04/13/2015          4641    DES MOINES    50315
# 243845       11806  02/04/2016          2626    DES MOINES    50311
# 243846       92353  07/23/2015          3920       CLINTON    52732
# 243850      200638  01/28/2015          3873    CORALVILLE    52241
# 243852      188260  11/02/2015          2588  CEDAR RAPIDS    52403
# 243855      138818  01/11/2016          2527    DES MOINES    50315
# 243856       59393  08/05/2015          4600    DES MOINES    50317
# 243857      176817  01/20/2015          3592    FORT DODGE    50501
# 243858       12867  03/11/2015          3820    SIOUX CITY    51103
#
#         County Number       County   Category  \
# 1                23.0      Clinton  1011200.0
# 2                 7.0   Black Hawk  1032080.0
# 4                77.0         Polk  1062300.0
# 5                52.0      Johnson  1031080.0
# 10               77.0         Polk  1031080.0
# 11               94.0      Webster  1062310.0
# 12               97.0     Woodbury  1081370.0
# 14               31.0      Dubuque  1011300.0
# 16                NaN          NaN  1042100.0
# 21                7.0   Black Hawk  1041100.0
# 23               77.0         Polk  1081200.0
# 25               57.0         Linn  1031080.0
# 26               57.0         Linn  1051150.0
# 29               82.0        Scott  1011100.0
# 42               82.0        Scott  1031080.0
# 43               77.0         Polk  1031080.0
# 46               57.0         Linn  1012100.0
# 49               31.0      Dubuque  1011100.0
# 50                7.0   Black Hawk  1012100.0
# 53               77.0         Polk  1081600.0
# 54                7.0   Black Hawk  1082900.0
# 59               94.0      Webster  1062310.0
# 62               77.0         Polk  1031080.0
# 66               31.0      Dubuque  1081300.0
# 69                7.0   Black Hawk  1031100.0
# 72                7.0   Black Hawk  1062310.0
# 74               77.0         Polk  1031200.0
# 75               77.0         Polk  1051010.0
# 82               82.0        Scott  1022100.0
# 83               17.0  Cerro Gordo  1032200.0
# ...               ...          ...        ...
# 243792           94.0      Webster  1012100.0
# 243793           31.0      Dubuque  1081200.0
# 243795           77.0         Polk  1071100.0
# 243796           31.0      Dubuque  1052010.0
# 243797           77.0         Polk  1062310.0
# 243798           97.0     Woodbury  1031200.0
# 243800           91.0       Warren  1081600.0
# 243803           97.0     Woodbury  1062200.0
# 243807           52.0      Johnson  1011200.0
# 243809           45.0       Howard  1051100.0
# 243810           77.0         Polk  1032080.0
# 243812            7.0   Black Hawk  1081390.0
# 243813           57.0         Linn  1032080.0
# 243821           31.0      Dubuque  1011100.0
# 243822            7.0   Black Hawk  1022100.0
# 243825           77.0         Polk  1022100.0
# 243826           57.0         Linn  1032080.0
# 243829           77.0         Polk  1041100.0
# 243837            7.0   Black Hawk  1042100.0
# 243839           77.0         Polk  1062200.0
# 243840           31.0      Dubuque  1011200.0
# 243843           77.0         Polk  1062310.0
# 243845           77.0         Polk  1031100.0
# 243846           23.0      Clinton  1062300.0
# 243850           52.0      Johnson  1011300.0
# 243852           57.0         Linn  1031080.0
# 243855           77.0         Polk  1081900.0
# 243856           77.0         Polk  1081390.0
# 243857           42.0       Hardin  1012100.0
# 243858           97.0     Woodbury  1012300.0
#
#                              Category Name  Vendor Number  Item Number  \
# 1                STRAIGHT BOURBON WHISKIES            259        18046
# 2                           IMPORTED VODKA            260        34456
# 4                             FLAVORED RUM             65        44557
# 5                           VODKA 80 PROOF            322        36595
# 10                          VODKA 80 PROOF            259        35416
# 11                              SPICED RUM            260        43333
# 12                     WATERMELON SCHNAPPS             65        82866
# 14                      TENNESSEE WHISKIES             85        26586
# 16                       IMPORTED DRY GINS             35        28236
# 21                       AMERICAN DRY GINS            300        31208
# 23                          CREAM LIQUEURS            260        68036
# 25                          VODKA 80 PROOF            205        36969
# 26                 MISCELLANEOUS  BRANDIES            125        53629
# 29                        BLENDED WHISKIES            297        23828
# 42                          VODKA 80 PROOF            434        36307
# 43                          VODKA 80 PROOF            260        37996
# 46                       CANADIAN WHISKIES             85        12476
# 49                        BLENDED WHISKIES            492        27433
# 50                       CANADIAN WHISKIES            260        11294
# 53                         WHISKEY LIQUEUR             85        86883
# 54      MISC. IMPORTED CORDIALS & LIQUEURS            421        69661
# 59                              SPICED RUM            259        43026
# 62                          VODKA 80 PROOF             55        37938
# 66                     PEPPERMINT SCHNAPPS            434        80571
# 69                         100 PROOF VODKA            300        36887
# 72                              SPICED RUM            260        43334
# 74                          VODKA FLAVORED            205        40598
# 75                 AMERICAN GRAPE BRANDIES            205        52591
# 82                                 TEQUILA            395        89196
# 83                   IMPORTED VODKA - MISC            434        36034
# ...                                    ...            ...          ...
# 243792                   CANADIAN WHISKIES            115        11774
# 243793                      CREAM LIQUEURS            260        68036
# 243795                  AMERICAN COCKTAILS            395        59154
# 243796             IMPORTED GRAPE BRANDIES            420        48106
# 243797                          SPICED RUM            240        45886
# 243798                      VODKA FLAVORED            205        40313
# 243800                     WHISKEY LIQUEUR            421        64858
# 243803    PUERTO RICO & VIRGIN ISLANDS RUM            434        45277
# 243807           STRAIGHT BOURBON WHISKIES            125        17206
# 243809                    APRICOT BRANDIES            434        54447
# 243810                      IMPORTED VODKA            277        34746
# 243812                   IMPORTED SCHNAPPS            260        65061
# 243813                      IMPORTED VODKA            370        34004
# 243821                    BLENDED WHISKIES             65        24466
# 243822                             TEQUILA            410        88294
# 243825                             TEQUILA             65        89836
# 243826                      IMPORTED VODKA            370        34006
# 243829                   AMERICAN DRY GINS            434        31656
# 243837                   IMPORTED DRY GINS             35        28236
# 243839    PUERTO RICO & VIRGIN ISLANDS RUM            434        46350
# 243840           STRAIGHT BOURBON WHISKIES             65        19061
# 243843                          SPICED RUM            259        43026
# 243845                     100 PROOF VODKA            297        35918
# 243846                        FLAVORED RUM             35        43136
# 243850                  TENNESSEE WHISKIES             85        86670
# 243852                      VODKA 80 PROOF            301        38178
# 243855  MISC. AMERICAN CORDIALS & LIQUEURS            205        77760
# 243856                   IMPORTED SCHNAPPS            421        69634
# 243857                   CANADIAN WHISKIES             65        15248
# 243858                      IRISH WHISKIES            370        15627
#
#                                 Item Description  Bottle Volume (ml)  \
# 1                      Evan Williams Green Label                 750
# 2                       Ketel One Imported Vodka                 750
# 4                          Cruzan Strawberry Rum                 750
# 5                                    Kinky Vodka                1750
# 10                        Burnett's Vodka 80 Prf                 750
# 11                 Captain Morgan Spiced Rum Pet                 200
# 12                    Dekuyper Watermelon Pucker                 750
# 14                                Gentleman Jack                 750
# 16                           Bombay Sapphire Gin                 750
# 21                             McCormick Gin Pet                1750
# 23                 Bailey's Original Irish Cream                 750
# 25                           New Amsterdam Vodka                 750
# 26                      Cedar Ridge Apple Brandy                 750
# 29                                     Five Star                1750
# 42                                 Hawkeye Vodka                1000
# 43                         Smirnoff Vodka 80 Prf                 750
# 46                     Canadian Mist Whiskey Pet                 750
# 49               Bird Dog Peach Flavored Whiskey                 750
# 50                   Crown Royal Canadian Whisky                 375
# 53                              Southern Comfort                 200
# 54               Dr. Mcgillicuddy's Vanilla Mini                 500
# 59                     Admiral Nelson Spiced Rum                 750
# 62                                    Skol Vodka                1750
# 66                Arrow Peppermint Schnapps Mini                 500
# 69                               McCormick Vodka                1000
# 72                     Captain Morgan Spiced Rum                 375
# 74                       New Amsterdam Red Berry                 375
# 75                          E & J Vs Brandy Mini                 500
# 82         Jose Cuervo Especial Reposado Tequila                 750
# 83                                   Pearl Peach                 750
# ...                                          ...                 ...
# 243792                              Black Velvet                 375
# 243793             Bailey's Original Irish Cream                 750
# 243795                   1800 Ultimate Margarita                1750
# 243796                        Hennessy Vs Cognac                 750
# 243797              Sailor Jerry Spiced Navy Rum                 750
# 243798                       New Amsterdam Peach                1750
# 243800  Fireball Cinnamon Whiskey Mini Dispenser                3000
# 243803                       Paramount White Rum                1000
# 243807                       Cedar Ridge Bourbon                 750
# 243809         Paramount Apricot Flavored Brandy                1000
# 243810          Stolichnaya Russian Vodka 80 Prf                 750
# 243812       Goldschlager Cinnamon Schnapps Mini                 600
# 243813              Absolut Swedish Vodka 80 Prf                 375
# 243821            Kessler Blend Whiskey Traveler                 750
# 243822                     Patron Silver Tequila                 375
# 243825                             Hornitos Gold                 750
# 243826              Absolut Swedish Vodka 80 Prf                 750
# 243829                             Paramount Gin                 750
# 243837                       Bombay Sapphire Gin                 750
# 243839                         Hawkeye Light Rum                1750
# 243840                             Jim Beam Mini                 500
# 243843                 Admiral Nelson Spiced Rum                 750
# 243845                        Five O'clock Vodka                1750
# 243846                             Bacardi Limon                 750
# 243850             Jack Daniel's Tennessee Honey                 750
# 243852                      Titos Handmade Vodka                1750
# 243855                                Viniq Ruby                 750
# 243856        Dr. Mcgillicuddy's Cherry Schnapps                 375
# 243857                      Windsor Canadian Pet                1750
# 243858                                   Jameson                1000
#
#        State Bottle Cost State Bottle Retail  Bottles Sold Sale (Dollars)  \
# 1                  $5.47               $8.21            12         $98.52
# 2                 $14.00              $21.00             2         $42.00
# 4                  $6.83              $10.25             1         $10.25
# 5                 $15.00              $22.50            18        $405.00
# 10                 $4.84               $7.26            12         $87.12
# 11                 $2.50               $3.75             6         $22.50
# 12                 $6.30               $9.45             1          $9.45
# 14                $20.01              $30.02            12        $360.24
# 16                $13.50              $20.25             3         $60.75
# 21                 $7.30              $10.95             3         $32.85
# 23                $13.25              $19.88             2         $39.76
# 25                 $6.90              $10.35            12        $124.20
# 26                $18.75              $28.13             6        $168.78
# 29                 $7.46              $11.19             6         $67.14
# 42                 $4.05               $6.08            24        $145.92
# 43                 $8.25              $12.38            12        $148.56
# 46                 $5.44               $8.16            12         $97.92
# 49                $10.00              $15.00             6         $90.00
# 50                 $7.75              $11.63             4         $46.52
# 53                 $2.51               $3.77             4         $15.08
# 54                 $4.96               $7.44             1          $7.44
# 59                 $5.78               $8.67            12        $104.04
# 62                 $7.11              $10.67             6         $64.02
# 66                 $4.55               $6.83             1          $6.83
# 69                 $4.13               $6.20            12         $74.40
# 72                 $5.00               $7.50            24        $180.00
# 74                 $3.50               $5.25             2         $10.50
# 75                 $5.92               $8.88             3         $26.64
# 82                $10.49              $15.74            12        $188.88
# 83                 $7.86              $11.79             2         $23.58
# ...                  ...                 ...           ...            ...
# 243792             $3.07               $4.61            24        $110.64
# 243793            $12.50              $18.75             4         $75.00
# 243795             $9.50              $14.25             6         $85.50
# 243796            $18.99              $28.49             3         $85.47
# 243797             $9.65              $14.48             2         $28.96
# 243798            $13.32              $19.98             1         $19.98
# 243800            $29.72              $44.58             2         $89.16
# 243803             $4.34               $6.51            12         $78.12
# 243807            $18.10              $27.15             6        $162.90
# 243809             $6.53               $9.80             4         $39.20
# 243810            $11.99              $17.99             3         $53.97
# 243812            $15.63              $23.45             2         $46.90
# 243813             $6.49               $9.74             4         $38.96
# 243821             $5.51               $8.27            12         $99.24
# 243822            $14.00              $21.00             3         $63.00
# 243825            $14.17              $21.26            12        $255.12
# 243826            $11.49              $17.24            12        $206.88
# 243829             $3.40               $5.10            12         $61.20
# 243837            $13.50              $20.25             3         $60.75
# 243839             $7.67              $11.51             6         $69.06
# 243840             $6.83              $10.25             1         $10.25
# 243843             $5.78               $8.67             3         $26.01
# 243845             $7.20              $10.80             6         $64.80
# 243846             $8.26              $12.39             2         $24.78
# 243850            $14.53              $21.80            12        $261.60
# 243852            $18.52              $27.78            12        $333.36
# 243855            $10.00              $15.00             3         $45.00
# 243856             $5.33               $8.00             3         $24.00
# 243857             $8.92              $13.38             6         $80.28
# 243858            $18.49              $27.74            12        $332.88
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# 1                       9.00                   2.38
# 2                       1.50                   0.40
# 4                       0.75                   0.20
# 5                      31.50                   8.32
# 10                      9.00                   2.38
# 11                      1.20                   0.32
# 12                      0.75                   0.20
# 14                      9.00                   2.38
# 16                      2.25                   0.59
# 21                      5.25                   1.39
# 23                      1.50                   0.40
# 25                      9.00                   2.38
# 26                      4.50                   1.19
# 29                     10.50                   2.77
# 42                     24.00                   6.34
# 43                      9.00                   2.38
# 46                      9.00                   2.38
# 49                      4.50                   1.19
# 50                      1.50                   0.40
# 53                      0.80                   0.21
# 54                      0.50                   0.13
# 59                      9.00                   2.38
# 62                     10.50                   2.77
# 66                      0.50                   0.13
# 69                     12.00                   3.17
# 72                      9.00                   2.38
# 74                      0.75                   0.20
# 75                      1.50                   0.40
# 82                      9.00                   2.38
# 83                      1.50                   0.40
# ...                      ...                    ...
# 243792                  9.00                   2.38
# 243793                  3.00                   0.79
# 243795                 10.50                   2.77
# 243796                  2.25                   0.59
# 243797                  1.50                   0.40
# 243798                  1.75                   0.46
# 243800                  6.00                   1.59
# 243803                 12.00                   3.17
# 243807                  4.50                   1.19
# 243809                  4.00                   1.06
# 243810                  2.25                   0.59
# 243812                  1.20                   0.32
# 243813                  1.50                   0.40
# 243821                  9.00                   2.38
# 243822                  1.12                   0.30
# 243825                  9.00                   2.38
# 243826                  9.00                   2.38
# 243829                  9.00                   2.38
# 243837                  2.25                   0.59
# 243839                 10.50                   2.77
# 243840                  0.50                   0.13
# 243843                  2.25                   0.59
# 243845                 10.50                   2.77
# 243846                  1.50                   0.40
# 243850                  9.00                   2.38
# 243852                 21.00                   5.55
# 243855                  2.25                   0.59
# 243856                  1.12                   0.30
# 243857                 10.50                   2.77
# 243858                 12.00                   3.17
#
# [94389 rows x 19 columns]

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
from sklearn import linear_model

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.
